# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('customer_purchase_data.csv')
df.head()
# Out:
#    Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 0   40       1   66120.267939                  8                0
# 1   20       1   23579.773583                  4                2
# 2   27       1  127821.306432                 11                2
# 3   24       1  137798.623120                 19                3
# 4   31       1   99300.964220                 19                1
#
#    TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# 0           30.568601               0                 5               1
# 1           38.240097               0                 5               0
# 2           31.633212               1                 0               1
# 3           46.167059               0                 4               1
# 4           19.823592               0                 0               1

# %% [markdown]
# # datafarmni jinsi jadvalini jinsi ustunidagi 0, 1 orniga jinsini yozib oldim

# %%
df.loc[df['Gender'] == 0, 'Gender'] = 'Male'
df.loc[df['Gender'] == 1, 'Gender'] = 'Female'
df.head()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8012\2266523888.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Male' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[df['Gender'] == 0, 'Gender'] = 'Male'
#    Age  Gender   AnnualIncome  NumberOfPurchases  ProductCategory  \
# 0   40  Female   66120.267939                  8                0
# 1   20  Female   23579.773583                  4                2
# 2   27  Female  127821.306432                 11                2
# 3   24  Female  137798.623120                 19                3
# 4   31  Female   99300.964220                 19                1
#
#    TimeSpentOnWebsite  LoyaltyProgram  DiscountsAvailed  PurchaseStatus
# 0           30.568601               0                 5               1
# 1           38.240097               0                 5               0
# ...

# %%
df.loc[df['ProductCategory'] == 0, 'ProductCategory'] = 'Electronics'
df.loc[df['ProductCategory'] == 1, 'ProductCategory'] = 'Clothing'
df.loc[df['ProductCategory'] == 2, 'ProductCategory'] = 'Home Goods'
df.loc[df['ProductCategory'] == 3, 'ProductCategory'] = 'Beauty'
df.loc[df['ProductCategory'] == 4, 'ProductCategory'] = 'Sports'
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8012\627172542.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Electronics' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[df['ProductCategory'] == 0, 'ProductCategory'] = 'Electronics'

# %%
category = {0: "Electronics", 1: "Clothing", 2: "Home Goods", 3: "Beauty", 4: "Sports"}

# %% [markdown]
# # aholini yillik daromadlari dollar($)

# %%
sns.set_style('whitegrid')
sns.histplot(df['AnnualIncome'], kde=True)
# Out:
# <Axes: xlabel='AnnualIncome', ylabel='Count'>

# %% [markdown]
# # erkaklar va ayollarni ortacha yillik daromadi

# %%
g = sns.catplot(x='Gender',
            y='AnnualIncome',
            data= df,
            kind='box',
            hue='Gender')

# %% [markdown]
# # qaysi turdagi maxsulotlar jami nechta sotilganligi

# %%
sns.displot(df['ProductCategory'])

# %% [markdown]
# # ayol va erkaklar qaysi turdagi mahsulotlarni koproq hard qiladi

# %%
g = sns.catplot(x='ProductCategory',
            data= df,
            kind='count',
            hue='ProductCategory',
            col='Gender')

# %%
g = sns.catplot(x='ProductCategory',
                y='AnnualIncome',
            data= df,
            kind='bar',
            hue='ProductCategory',
            col='Gender')

# %%
g = sns.catplot(x='ProductCategory',
                y='AnnualIncome',
            data= df,
            kind='box',
            hue='ProductCategory',
            col='Gender')

# %%
sns.scatterplot(data=df,
                y='NumberOfPurchases',
                x='Age',
                hue='Gender')
# Out:
# <Axes: xlabel='Age', ylabel='NumberOfPurchases'>

# %%
sns.regplot(data=df, x="AnnualIncome", y="NumberOfPurchases" )
# Out:
# <Axes: xlabel='AnnualIncome', ylabel='NumberOfPurchases'>

# %%
sns.lmplot(data=df, x="AnnualIncome", y="NumberOfPurchases" )
